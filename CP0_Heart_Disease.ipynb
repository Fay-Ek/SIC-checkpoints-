# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("heart.csv")

# %%
data.shape
# Out:
# (303, 14)

# %%
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
print('minimum age ',data['age'].unique().min())
print('maximum age ',data['age'].unique().max())
# Out:
# minimum age  29
# maximum age  77

# %%
data['sex'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
data['cp'].unique()
# Out:
# array([3, 2, 1, 0], dtype=int64)

# %%
corr = data.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_b30aa_row0_col0, #T_b30aa_row1_col1, #T_b30aa_row2_col2, #T_b30aa_row3_col3, #T_b30aa_row4_col4, #T_b30aa_row5_col5, #T_b30aa_row6_col6, #T_b30aa_row7_col7, #T_b30aa_row8_col8, #T_b30aa_row9_col9, #T_b30aa_row10_col10, #T_b30aa_row11_col11, #T_b30aa_row12_col12, #T_b30aa_row13_col13 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_b30aa_row0_col1 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_b30aa_row0_col2, #T_b30aa_row4_col3, #T_b30aa_row5_col12 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_b30aa_row0_col3, #T_b30aa_row5_col9, #T_b30aa_row10_col2, #T_b30aa_row11_col12 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_b30aa_row0_col4 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_b30aa_row0_col5 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_b30aa_row0_col6, #T_b30aa_row2_col8 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# ...

# %%
'''
plt.plot(data['age', y)
plt.title("Curve plotted using the given points")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()
'''

# %%
ax = data.plot.hist(column=["age"], by="target")

# %%
plt.hist(data['age'])
# Out:
# (array([ 1., 11., 33., 38., 37., 60., 63., 43., 14.,  3.]),
#  array([29. , 33.8, 38.6, 43.4, 48.2, 53. , 57.8, 62.6, 67.4, 72.2, 77. ]),
#  <BarContainer object of 10 artists>)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
Output = pd.DataFrame(data['target'])
Input = data.drop(columns = 'target')

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(Input)
Input = pd.DataFrame(scaler.transform(Input))
a.head()
# Out:
#          0    1         2         3         4    5    6         7    8   \
# 0  0.708333  1.0  1.000000  0.481132  0.244292  1.0  0.0  0.603053  0.0
# 1  0.166667  1.0  0.666667  0.339623  0.283105  0.0  0.5  0.885496  0.0
# 2  0.250000  0.0  0.333333  0.339623  0.178082  0.0  0.0  0.770992  0.0
# 3  0.562500  1.0  0.333333  0.245283  0.251142  0.0  0.5  0.816794  0.0
# 4  0.583333  0.0  0.000000  0.245283  0.520548  0.0  0.5  0.702290  1.0
#
#          9    10   11        12
# 0  0.370968  0.0  0.0  0.333333
# 1  0.564516  0.0  0.0  0.666667
# 2  0.225806  1.0  0.0  0.666667
# 3  0.129032  1.0  0.0  0.666667
# 4  0.096774  1.0  0.0  0.666667

# %%
Input.shape
# Out:
# (303, 13)

# %%
Input_train, Input_test = train_test_split(Input, test_size=0.2, random_state=42)
Output_train, Output_test = train_test_split(Output, test_size=0.2, random_state=42)

# %%
clf = LogisticRegression(random_state=0).fit(Input_train, Output_train)
# Out:
# C:\Users\fayca\anaconda3\lib\site-packages\sklearn\utils\validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
y_predicted = clf.predict(Input_test)

# %%
from sklearn import metrics
metrics.accuracy_score(Output_test,y_predicted)
# Out:
# 0.8524590163934426

# %%
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
cm = confusion_matrix(Output_test, y_predicted, labels=clf.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=clf.classes_)
disp.plot()

# %%
y_pred_proba = clf.predict_proba(Input_test)[::,1]
fpr, tpr, _ = metrics.roc_curve(Output_test,  y_pred_proba)

#create ROC curve
plt.plot(fpr,tpr)
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
print(clf.predict_proba(Input_test)[::,1].size)
# Out:
# 61

# %%
print(clf.predict_proba(Input_test).size)
# Out:
# 122
