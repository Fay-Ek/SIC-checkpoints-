# %% [markdown]
# # If you happy and I know it you can enter my House
#
# You'll see how you can in a couple of hours build a deep learning algorithm.

# %%
import numpy as np
from sklearn.metrics import confusion_matrix
import seaborn as sns
import h5py
from keras import layers
from keras.layers import Input, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D
from keras.layers import AveragePooling2D, MaxPooling2D, Dropout, GlobalMaxPooling2D, GlobalAveragePooling2D
from keras.models import Model
from keras.preprocessing import image
from keras.utils import layer_utils
from keras.utils.data_utils import get_file
from keras.applications.imagenet_utils import preprocess_input
from keras.models import Sequential

import pydot
from IPython.display import SVG


import keras.backend as K
K.set_image_data_format('channels_last')
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow

# %%
def load_dataset(path_to_train, path_to_test):
    train_dataset = h5py.File(path_to_train)
    train_x = np.array(train_dataset['train_set_x'][:])
    train_y = np.array(train_dataset['train_set_y'][:])

    test_dataset = h5py.File(path_to_test)
    test_x = np.array(test_dataset['test_set_x'][:])
    test_y = np.array(test_dataset['test_set_y'][:])

    # y reshaped
    train_y = train_y.reshape((1, train_x.shape[0]))
    test_y = test_y.reshape((1, test_y.shape[0]))

    return train_x, train_y, test_x, test_y

# %% [markdown]
# This dataset can be used to solve the Happy House problem.
# Where, we allow a person to enter the house only if he/she is smiling!
# So, a smile detector!

# %% [markdown]
# ![Texte alternatif…](https://raw.githubusercontent.com/Kulbear/deep-learning-coursera/master/Convolutional%20Neural%20Networks/images/house-members.png)

# %% [markdown]
# Details of the "Happy" dataset:
#
# * Images are of shape (64,64,3)
# * Training: 600 pictures
# * Test: 150 pictures

# %% [markdown]
# # Load Dataset

# %%
X_train_orig, Y_train_orig, X_test_orig, Y_test_orig = load_dataset("train_happy.h5","test_happy.h5")

# Normalize image vectors
X_train = X_train_orig/255.
X_test = X_test_orig/255.

# Reshape
Y_train = Y_train_orig.T
Y_test = Y_test_orig.T

print ("number of training examples = " + str(X_train.shape[0]))
print ("number of test examples = " + str(X_test.shape[0]))
print ("X_train shape: " + str(X_train.shape))
print ("Y_train shape: " + str(Y_train.shape))
print ("X_test shape: " + str(X_test.shape))
print ("Y_test shape: " + str(Y_test.shape))
# Out:
# number of training examples = 600
# number of test examples = 150
# X_train shape: (600, 64, 64, 3)
# Y_train shape: (600, 1)
# X_test shape: (150, 64, 64, 3)
# Y_test shape: (150, 1)

# %%
# Sample image from dataset
print("Image shape :",X_train_orig[10].shape)
imshow(X_train_orig[10])
# Out:
# Image shape : (64, 64, 3)

# %% [markdown]
# # Building Model

# %% [markdown]
# _________________________________________________________________
#
# conv2d_3 (Conv2D)            (None, 64, 64, 32)        4736
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 64, 64, 32)        128
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 32768)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 32769
# _________________________________________________________________

# %%
model = Sequential()

model.add(Conv2D(filters=32, kernel_size=(3,3), activation='relu', padding='same',input_shape=(64, 64, 3)))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(filters=32, kernel_size=(3,3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2,2)))


model.add(Flatten())


model.add(Dense(units = 64, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(units = 64, activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(units = 1, activation = 'sigmoid'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 64, 64, 32)        896
#
#  max_pooling2d_2 (MaxPooling  (None, 32, 32, 32)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 32, 32, 32)        9248
#
#  max_pooling2d_3 (MaxPooling  (None, 16, 16, 32)       0
#  2D)
#
#  flatten_1 (Flatten)         (None, 8192)              0
#
#  dense_3 (Dense)             (None, 64)                524352
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 64)                4160
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 538,721
# Trainable params: 538,721
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='Adam', loss='binary_crossentropy', metrics=["accuracy"])

# %%
history = model.fit(X_train,
                    Y_train,
                    batch_size=10,
                    epochs=50,
                    verbose=1,
                    validation_split=0.2)
# Out:
# Epoch 1/50
# 48/48 [==============================] - 3s 40ms/step - loss: 0.7049 - accuracy: 0.5271 - val_loss: 0.6891 - val_accuracy: 0.4500
# Epoch 2/50
# 48/48 [==============================] - 2s 37ms/step - loss: 0.6371 - accuracy: 0.6687 - val_loss: 0.5004 - val_accuracy: 0.8417
# Epoch 3/50
# 48/48 [==============================] - 2s 37ms/step - loss: 0.4556 - accuracy: 0.7667 - val_loss: 0.2682 - val_accuracy: 0.9167
# Epoch 4/50
# 48/48 [==============================] - 2s 38ms/step - loss: 0.3244 - accuracy: 0.8708 - val_loss: 0.2203 - val_accuracy: 0.9250
# Epoch 5/50
# 48/48 [==============================] - 2s 41ms/step - loss: 0.2440 - accuracy: 0.9229 - val_loss: 0.1773 - val_accuracy: 0.9333
# Epoch 6/50
# 48/48 [==============================] - 2s 40ms/step - loss: 0.1726 - accuracy: 0.9438 - val_loss: 0.1071 - val_accuracy: 0.9750
# Epoch 7/50
# 48/48 [==============================] - 2s 39ms/step - loss: 0.1821 - accuracy: 0.9292 - val_loss: 0.0996 - val_accuracy: 0.9833
# Epoch 8/50
# 48/48 [==============================] - 2s 42ms/step - loss: 0.1293 - accuracy: 0.9604 - val_loss: 0.1522 - val_accuracy: 0.9167
# Epoch 9/50
# 48/48 [==============================] - 2s 45ms/step - loss: 0.1217 - accuracy: 0.9521 - val_loss: 0.0734 - val_accuracy: 0.9833
# Epoch 10/50
# 48/48 [==============================] - 2s 38ms/step - loss: 0.1228 - accuracy: 0.9521 - val_loss: 0.0824 - val_accuracy: 0.9583
# Epoch 11/50
# 48/48 [==============================] - 2s 40ms/step - loss: 0.0973 - accuracy: 0.9625 - val_loss: 0.0859 - val_accuracy: 0.9667
# Epoch 12/50
# 48/48 [==============================] - 2s 43ms/step - loss: 0.0707 - accuracy: 0.9833 - val_loss: 0.0689 - val_accuracy: 0.9667
# Epoch 13/50
# 48/48 [==============================] - 2s 41ms/step - loss: 0.0699 - accuracy: 0.9771 - val_loss: 0.0491 - val_accuracy: 0.9833
# Epoch 14/50
# 48/48 [==============================] - 2s 38ms/step - loss: 0.0653 - accuracy: 0.9875 - val_loss: 0.0911 - val_accuracy: 0.9583
# Epoch 15/50
# 48/48 [==============================] - 2s 35ms/step - loss: 0.0670 - accuracy: 0.9812 - val_loss: 0.0361 - val_accuracy: 0.9833
# Epoch 16/50
# 48/48 [==============================] - 2s 37ms/step - loss: 0.0690 - accuracy: 0.9854 - val_loss: 0.0486 - val_accuracy: 0.9667
# Epoch 17/50
# 48/48 [==============================] - 2s 35ms/step - loss: 0.0707 - accuracy: 0.9667 - val_loss: 0.0455 - val_accuracy: 0.9833
# Epoch 18/50
# 48/48 [==============================] - 2s 44ms/step - loss: 0.0452 - accuracy: 0.9812 - val_loss: 0.0909 - val_accuracy: 0.9750
# Epoch 19/50
# 48/48 [==============================] - 2s 46ms/step - loss: 0.0535 - accuracy: 0.9833 - val_loss: 0.0426 - val_accuracy: 0.9833
# Epoch 20/50
# 48/48 [==============================] - 2s 40ms/step - loss: 0.0418 - accuracy: 0.9875 - val_loss: 0.0525 - val_accuracy: 0.9750
# Epoch 21/50
# 48/48 [==============================] - 2s 41ms/step - loss: 0.0254 - accuracy: 0.9917 - val_loss: 0.0518 - val_accuracy: 0.9833
# Epoch 22/50
# 48/48 [==============================] - 2s 39ms/step - loss: 0.0415 - accuracy: 0.9896 - val_loss: 0.0392 - val_accuracy: 0.9750
# Epoch 23/50
# 48/48 [==============================] - 2s 37ms/step - loss: 0.0281 - accuracy: 0.9937 - val_loss: 0.0630 - val_accuracy: 0.9750
# Epoch 24/50
# 48/48 [==============================] - 2s 43ms/step - loss: 0.0475 - accuracy: 0.9792 - val_loss: 0.0631 - val_accuracy: 0.9750
# Epoch 25/50
# 48/48 [==============================] - 2s 42ms/step - loss: 0.0421 - accuracy: 0.9854 - val_loss: 0.0425 - val_accuracy: 0.9667
# Epoch 26/50
# 48/48 [==============================] - 2s 41ms/step - loss: 0.0305 - accuracy: 0.9917 - val_loss: 0.0655 - val_accuracy: 0.9667
# Epoch 27/50
# 48/48 [==============================] - 2s 39ms/step - loss: 0.0196 - accuracy: 0.9937 - val_loss: 0.0577 - val_accuracy: 0.9833
# Epoch 28/50
# 48/48 [==============================] - 2s 41ms/step - loss: 0.0209 - accuracy: 0.9937 - val_loss: 0.0485 - val_accuracy: 0.9833
# Epoch 29/50
# 48/48 [==============================] - 2s 38ms/step - loss: 0.0258 - accuracy: 0.9917 - val_loss: 0.0383 - val_accuracy: 0.9917
# Epoch 30/50
# 48/48 [==============================] - 2s 39ms/step - loss: 0.0180 - accuracy: 0.9958 - val_loss: 0.0481 - val_accuracy: 0.9750
# Epoch 31/50
# 48/48 [==============================] - 2s 43ms/step - loss: 0.0233 - accuracy: 0.9937 - val_loss: 0.0424 - val_accuracy: 0.9667
# Epoch 32/50
# 48/48 [==============================] - 2s 42ms/step - loss: 0.0536 - accuracy: 0.9854 - val_loss: 0.0372 - val_accuracy: 0.9750
# Epoch 33/50
# 48/48 [==============================] - 2s 41ms/step - loss: 0.0287 - accuracy: 0.9917 - val_loss: 0.0636 - val_accuracy: 0.9750
# Epoch 34/50
# 48/48 [==============================] - 2s 38ms/step - loss: 0.0339 - accuracy: 0.9917 - val_loss: 0.0256 - val_accuracy: 0.9833
# Epoch 35/50
# 48/48 [==============================] - 2s 40ms/step - loss: 0.0230 - accuracy: 0.9937 - val_loss: 0.0324 - val_accuracy: 0.9917
# Epoch 36/50
# 48/48 [==============================] - 2s 40ms/step - loss: 0.0210 - accuracy: 0.9958 - val_loss: 0.0228 - val_accuracy: 0.9917
# Epoch 37/50
# 48/48 [==============================] - 2s 39ms/step - loss: 0.0216 - accuracy: 0.9937 - val_loss: 0.0266 - val_accuracy: 0.9833
# Epoch 38/50
# 48/48 [==============================] - 2s 43ms/step - loss: 0.0130 - accuracy: 0.9979 - val_loss: 0.0329 - val_accuracy: 0.9917
# Epoch 39/50
# 48/48 [==============================] - 2s 40ms/step - loss: 0.0145 - accuracy: 0.9958 - val_loss: 0.0173 - val_accuracy: 0.9917
# Epoch 40/50
# 48/48 [==============================] - 2s 43ms/step - loss: 0.0120 - accuracy: 0.9979 - val_loss: 0.0332 - val_accuracy: 0.9917
# Epoch 41/50
# 48/48 [==============================] - 2s 40ms/step - loss: 0.0124 - accuracy: 0.9958 - val_loss: 0.0456 - val_accuracy: 0.9833
# Epoch 42/50
# 48/48 [==============================] - 2s 44ms/step - loss: 0.0121 - accuracy: 0.9958 - val_loss: 0.1675 - val_accuracy: 0.9667
# Epoch 43/50
# 48/48 [==============================] - 2s 37ms/step - loss: 0.0387 - accuracy: 0.9875 - val_loss: 0.0487 - val_accuracy: 0.9750
# Epoch 44/50
# 48/48 [==============================] - 2s 37ms/step - loss: 0.0623 - accuracy: 0.9771 - val_loss: 0.2510 - val_accuracy: 0.9333
# Epoch 45/50
# 48/48 [==============================] - 2s 37ms/step - loss: 0.0389 - accuracy: 0.9854 - val_loss: 0.0619 - val_accuracy: 0.9750
# Epoch 46/50
# 48/48 [==============================] - 2s 49ms/step - loss: 0.0253 - accuracy: 0.9875 - val_loss: 0.0607 - val_accuracy: 0.9750
# Epoch 47/50
# 48/48 [==============================] - 2s 41ms/step - loss: 0.0116 - accuracy: 0.9937 - val_loss: 0.0450 - val_accuracy: 0.9750
# Epoch 48/50
# 48/48 [==============================] - 2s 45ms/step - loss: 0.0144 - accuracy: 0.9979 - val_loss: 0.0898 - val_accuracy: 0.9750
# Epoch 49/50
# 48/48 [==============================] - 2s 50ms/step - loss: 0.0126 - accuracy: 0.9958 - val_loss: 0.0621 - val_accuracy: 0.9583
# Epoch 50/50
# 48/48 [==============================] - 2s 38ms/step - loss: 0.0089 - accuracy: 0.9979 - val_loss: 0.0594 - val_accuracy: 0.9750

# %% [markdown]
# # Evaluate / Test

# %%
train_accuracy = history.history['val_accuracy']
train_loss = history.history['val_loss']

count = range(len(train_accuracy))
plt.plot(count, train_accuracy, label='Training accuracy')
plt.plot(count, train_loss, label='Training Loss')
plt.title('epochs vs Training Loss')
plt.legend()

# %% [markdown]
# Evaluate Test set

# %%
# Code Here
score = model.evaluate(X_test, Y_test)
print('Accuracy of test => ',score[1])
# Out:
# 5/5 [==============================] - 0s 26ms/step - loss: 0.1811 - accuracy: 0.9533
# Accuracy of test =>  0.95333331823349

# %% [markdown]
# Confusion Matrix

# %%
# Code Here
pred = model.predict(X_test)
predictions = [float(np.round(x)) for x in pred]
from sklearn.metrics import f1_score, classification_report,confusion_matrix, ConfusionMatrixDisplay
def conf_matrix(y_test, y_pred, model):
    cm = confusion_matrix(y_test, y_pred, labels=[0, 1])
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[0, 1])
    fig, ax = plt.subplots(figsize=(15,12))
    disp.plot(ax=ax)
    plt.show()
conf_matrix(Y_test, predictions, model)

# %% [markdown]
# # Note
#
# Before you submit your work
#
# * You should compare different optimizers
#
# ---
#
# * Display images with Predicted & expected labels (Happy-sad)

# %%
text_labels = ["Sad", "Happy"]
plt.figure(figsize=(10,10))
for i in range(10):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid('off')
    
    img_index = np.random.randint(0, 150)
    plt.imshow(X_test_orig[img_index], cmap=plt.cm.gray)
    actual_label  = Y_test[img_index][0]
    predicted_label = int(predictions[img_index])
    
    plt.xlabel("Real: {} ({})\n Predicted: {} ({})".format(
        actual_label, text_labels[actual_label], predicted_label, text_labels[predicted_label]
    ))
    
plt.tight_layout()
plt.show()

# %%
#Different optimizer to compare 
model.compile(optimizer="Adamax", loss='binary_crossentropy', metrics=["accuracy"])
model.compile(optimizer="Nadam", loss='binary_crossentropy', metrics=["accuracy"])
model.compile(optimizer="Ftrl", loss='binary_crossentropy', metrics=["accuracy"])

# %%
#try with RMSprop
from tensorflow.keras.optimizers import RMSprop
model.compile(optimizer=RMSprop(), loss='binary_crossentropy', metrics=["accuracy"])
history = model.fit(X_train,
                    Y_train,
                    batch_size=10,
                    epochs=50,
                    verbose=1,
                    validation_split=0.2)
#### Evaluate
train_accuracy = history.history['val_accuracy']
train_loss = history.history['val_loss']

count = range(len(train_accuracy))
plt.plot(count, train_accuracy, label='Training accuracy')
plt.plot(count, train_loss, label='Training Loss')
plt.title('epochs vs Training Loss')
plt.legend()
# Out:
# Epoch 1/50
# 48/48 [==============================] - 3s 45ms/step - loss: 0.0116 - accuracy: 0.9958 - val_loss: 0.0543 - val_accuracy: 0.9833
# Epoch 2/50
# 48/48 [==============================] - 2s 37ms/step - loss: 0.0215 - accuracy: 0.9979 - val_loss: 0.0782 - val_accuracy: 0.9750
# Epoch 3/50
# 48/48 [==============================] - 2s 38ms/step - loss: 0.0178 - accuracy: 0.9917 - val_loss: 0.0826 - val_accuracy: 0.9750
# Epoch 4/50
# 48/48 [==============================] - 2s 41ms/step - loss: 0.0142 - accuracy: 0.9937 - val_loss: 0.0302 - val_accuracy: 0.9917
# Epoch 5/50
# 48/48 [==============================] - 2s 46ms/step - loss: 0.0125 - accuracy: 0.9937 - val_loss: 0.0544 - val_accuracy: 0.9583
# Epoch 6/50
# 48/48 [==============================] - 2s 43ms/step - loss: 0.0120 - accuracy: 0.9937 - val_loss: 0.0740 - val_accuracy: 0.9833
# Epoch 7/50
# 48/48 [==============================] - 2s 40ms/step - loss: 0.0082 - accuracy: 0.9979 - val_loss: 0.0685 - val_accuracy: 0.9833
# Epoch 8/50
# 48/48 [==============================] - 2s 41ms/step - loss: 0.0169 - accuracy: 0.9958 - val_loss: 0.0291 - val_accuracy: 0.9917
# Epoch 9/50
# 48/48 [==============================] - 2s 42ms/step - loss: 0.0094 - accuracy: 0.9979 - val_loss: 0.0445 - val_accuracy: 0.9917
# Epoch 10/50
# 48/48 [==============================] - 2s 41ms/step - loss: 0.0077 - accuracy: 0.9979 - val_loss: 0.0213 - val_accuracy: 0.9917
# Epoch 11/50
# 48/48 [==============================] - 2s 40ms/step - loss: 0.0148 - accuracy: 0.9896 - val_loss: 0.0334 - val_accuracy: 0.9833
# Epoch 12/50
# 48/48 [==============================] - 2s 41ms/step - loss: 0.0109 - accuracy: 0.9958 - val_loss: 0.0062 - val_accuracy: 1.0000
# Epoch 13/50
# 48/48 [==============================] - 2s 40ms/step - loss: 0.0035 - accuracy: 0.9979 - val_loss: 0.0190 - val_accuracy: 0.9833
# Epoch 14/50
# 48/48 [==============================] - 2s 38ms/step - loss: 0.0205 - accuracy: 0.9958 - val_loss: 0.0273 - val_accuracy: 0.9833
# Epoch 15/50
# 48/48 [==============================] - 2s 37ms/step - loss: 0.0081 - accuracy: 0.9958 - val_loss: 0.0477 - val_accuracy: 0.9917
# Epoch 16/50
# 48/48 [==============================] - 2s 37ms/step - loss: 0.0093 - accuracy: 0.9958 - val_loss: 0.1373 - val_accuracy: 0.9583
# Epoch 17/50
# 48/48 [==============================] - 2s 37ms/step - loss: 0.0065 - accuracy: 0.9979 - val_loss: 0.1037 - val_accuracy: 0.9833
# Epoch 18/50
# 48/48 [==============================] - 2s 38ms/step - loss: 0.0142 - accuracy: 0.9937 - val_loss: 0.0116 - val_accuracy: 0.9917
# Epoch 19/50
# 48/48 [==============================] - 2s 39ms/step - loss: 0.0042 - accuracy: 0.9979 - val_loss: 0.0540 - val_accuracy: 0.9833
# Epoch 20/50
# 48/48 [==============================] - 2s 41ms/step - loss: 0.0164 - accuracy: 0.9937 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 21/50
# 48/48 [==============================] - 2s 41ms/step - loss: 0.0047 - accuracy: 0.9979 - val_loss: 0.0260 - val_accuracy: 0.9917
# Epoch 22/50
# 48/48 [==============================] - 2s 40ms/step - loss: 0.0158 - accuracy: 0.9958 - val_loss: 0.0547 - val_accuracy: 0.9833
# Epoch 23/50
# 48/48 [==============================] - 2s 38ms/step - loss: 0.0199 - accuracy: 0.9979 - val_loss: 0.0136 - val_accuracy: 0.9917
# Epoch 24/50
# 48/48 [==============================] - 2s 39ms/step - loss: 0.0066 - accuracy: 0.9958 - val_loss: 0.0202 - val_accuracy: 0.9917
# Epoch 25/50
# 48/48 [==============================] - 2s 40ms/step - loss: 0.0168 - accuracy: 0.9937 - val_loss: 0.0616 - val_accuracy: 0.9833
# Epoch 26/50
# 48/48 [==============================] - 2s 39ms/step - loss: 0.0059 - accuracy: 0.9958 - val_loss: 0.0381 - val_accuracy: 0.9833
# Epoch 27/50
# 48/48 [==============================] - 2s 39ms/step - loss: 0.0314 - accuracy: 0.9917 - val_loss: 0.0128 - val_accuracy: 0.9917
# Epoch 28/50
# 48/48 [==============================] - 2s 39ms/step - loss: 0.0104 - accuracy: 0.9979 - val_loss: 0.0477 - val_accuracy: 0.9750
# Epoch 29/50
# 48/48 [==============================] - 2s 43ms/step - loss: 0.0052 - accuracy: 0.9979 - val_loss: 0.0325 - val_accuracy: 0.9833
# Epoch 30/50
# 48/48 [==============================] - 2s 45ms/step - loss: 0.0092 - accuracy: 0.9958 - val_loss: 0.0181 - val_accuracy: 0.9917
# Epoch 31/50
# 48/48 [==============================] - 2s 41ms/step - loss: 0.0188 - accuracy: 0.9917 - val_loss: 0.0622 - val_accuracy: 0.9833
# Epoch 32/50
# 48/48 [==============================] - 2s 41ms/step - loss: 0.0118 - accuracy: 0.9958 - val_loss: 0.0917 - val_accuracy: 0.9833
# Epoch 33/50
# 48/48 [==============================] - 2s 41ms/step - loss: 0.0182 - accuracy: 0.9958 - val_loss: 0.0158 - val_accuracy: 1.0000
# Epoch 34/50
# 48/48 [==============================] - 2s 40ms/step - loss: 0.0096 - accuracy: 0.9979 - val_loss: 0.0435 - val_accuracy: 0.9917
# Epoch 35/50
# 48/48 [==============================] - 2s 42ms/step - loss: 0.0048 - accuracy: 0.9958 - val_loss: 0.0119 - val_accuracy: 1.0000
# Epoch 36/50
# 48/48 [==============================] - 2s 44ms/step - loss: 0.0194 - accuracy: 0.9937 - val_loss: 0.0337 - val_accuracy: 0.9833
# Epoch 37/50
# 48/48 [==============================] - 2s 48ms/step - loss: 0.0167 - accuracy: 0.9937 - val_loss: 0.0957 - val_accuracy: 0.9833
# Epoch 38/50
# 48/48 [==============================] - 3s 53ms/step - loss: 0.0042 - accuracy: 0.9958 - val_loss: 0.0336 - val_accuracy: 0.9917
# Epoch 39/50
# 48/48 [==============================] - 2s 47ms/step - loss: 0.0061 - accuracy: 0.9979 - val_loss: 0.0189 - val_accuracy: 0.9917
# Epoch 40/50
# 48/48 [==============================] - 2s 43ms/step - loss: 0.0113 - accuracy: 0.9979 - val_loss: 0.0836 - val_accuracy: 0.9833
# Epoch 41/50
# 48/48 [==============================] - 2s 49ms/step - loss: 0.0156 - accuracy: 0.9958 - val_loss: 0.0751 - val_accuracy: 0.9750
# Epoch 42/50
# 48/48 [==============================] - 3s 52ms/step - loss: 0.0022 - accuracy: 0.9979 - val_loss: 0.0073 - val_accuracy: 0.9917
# Epoch 43/50
# 48/48 [==============================] - 2s 50ms/step - loss: 0.0094 - accuracy: 0.9979 - val_loss: 0.0695 - val_accuracy: 0.9833
# Epoch 44/50
# 48/48 [==============================] - 3s 53ms/step - loss: 0.0077 - accuracy: 0.9979 - val_loss: 0.0189 - val_accuracy: 0.9917
# Epoch 45/50
# 48/48 [==============================] - 3s 68ms/step - loss: 0.0127 - accuracy: 0.9958 - val_loss: 0.0285 - val_accuracy: 0.9917
# Epoch 46/50
# 48/48 [==============================] - 2s 49ms/step - loss: 0.0046 - accuracy: 0.9979 - val_loss: 0.0650 - val_accuracy: 0.9750
# Epoch 47/50
# 48/48 [==============================] - 2s 47ms/step - loss: 0.0035 - accuracy: 0.9979 - val_loss: 0.0564 - val_accuracy: 0.9833
# Epoch 48/50
# 48/48 [==============================] - 2s 48ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0539 - val_accuracy: 0.9833
# Epoch 49/50
# 48/48 [==============================] - 2s 48ms/step - loss: 4.2469e-05 - accuracy: 1.0000 - val_loss: 0.1062 - val_accuracy: 0.9833
# Epoch 50/50
# 48/48 [==============================] - 2s 50ms/step - loss: 0.0125 - accuracy: 0.9958 - val_loss: 0.0496 - val_accuracy: 0.9917

# %%
#Evaluat new model with test 
score = model.evaluate(X_test, Y_test)
print('Accuracy of test => ',score[1])
# Out:
# 5/5 [==============================] - 0s 25ms/step - loss: 0.4109 - accuracy: 0.9600
# Accuracy of test =>  0.9599999785423279

# %%
#RMSprop give a better accuracy than Adam
